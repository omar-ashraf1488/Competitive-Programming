# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Answer:**

# %%
def main():
  letterInputList = list(set(input()[1:-1]))
  try:
    letterInputList.remove(' ')
    letterInputList.remove(',')
  except: pass
  print(len(letterInputList))

if __name__ == '__main__':
    main()
# Out:
# {}
# 0
