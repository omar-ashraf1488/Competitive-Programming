# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Answer:**

# %%
import math

def main():
  n, t, k, d = map(int, input().split())

  if n < k:
    return print("NO")
  
  timeTobakeAllCakes =  math.ceil(n / k) * t

  if timeTobackallCakes <= (t + d):
    print("NO")
  else:
    print("YES")

if __name__ == '__main__':
    main()
