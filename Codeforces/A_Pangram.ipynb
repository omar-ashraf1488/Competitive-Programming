# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Answer:**

# %%
def main():
  n = int(input())
  string = set(str(input().lower()))

  if len(string) == 26:
    print("YES")
  else:
    print("NO") 
           
if __name__ == '__main__':
    main()
