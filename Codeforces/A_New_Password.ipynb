# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Answer:**

# %%
def main():
  n, k =  map(int, input().split())
  '''
  for example: n=4 , k=3
  "abcdefghijklmnopqrstuvwxyz"[:3] ->abc
  abc * n ->abc * 4 = abcabcabcabc
  abcabcabcabc[:n] -> abcabcabcabc[:4] = abca
  '''
  print(("abcdefghijklmnopqrstuvwxyz"[:k]*n)[:n])
        

if __name__ == '__main__':
    main()
