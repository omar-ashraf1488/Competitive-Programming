# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Answer:**

# %%
def main():
  string = list(input().split("+"))
  if len(string) > 1:
    string.sort()
    print('+'.join(string))
  else:
    print(string[0])

if __name__ == '__main__':
    main()
