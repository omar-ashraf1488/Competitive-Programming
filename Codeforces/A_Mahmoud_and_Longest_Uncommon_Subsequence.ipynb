# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Answer:**

# %%
def main():
  a = input()
  b = input()

  if len(a) > len(b):
    print(len(a))
  elif a == b:
    print(-1)
  else:
    print(len(b))
                    
      
if __name__ == '__main__':
    main()
